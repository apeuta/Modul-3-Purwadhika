# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_olivetti_faces

# %%
data = fetch_olivetti_faces()
dir(data)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /Users/apeuta/scikit_learn_data
# ['DESCR', 'data', 'images', 'target']

# %% [markdown]
# Total "data" = [4096] </br>
# Total "images" = [64 x 64] </br>
# Datanya sama hanya beda shape

# %%
plt.imshow(data["images"][0], cmap="gray")

# %%
plt.figure(figsize= (12,5))
for i in range(10):
    orang = 37
    plt.subplot(2, 5, i+1)
    plt.imshow(data["images"][i + (10 * (orang - 1))], cmap= "gray")

# %%
df = pd.DataFrame(data["data"])
df
# Out:
#          0         1         2         3         4         5         6     \
# 0    0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1    0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2    0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3    0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4    0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  0.632231  0.648760  0.640496  0.661157
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 397  0.500000  0.533058  0.607438  0.628099  0.657025  0.632231  0.657025
# 398  0.214876  0.219008  0.219008  0.223140  0.210744  0.202479  0.276859
# 399  0.516529  0.462810  0.280992  0.252066  0.247934  0.367769  0.574380
#
#          7         8         9     ...      4086      4087      4088  \
# ...

# %%
df["target"] = data["target"]
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.309917  0.367769  0.417355  0.442149  0.528926  0.607438  0.657025
# 1    0.454545  0.471074  0.512397  0.557851  0.595041  0.640496  0.681818
# 2    0.318182  0.400826  0.491736  0.528926  0.586777  0.657025  0.681818
# 3    0.198347  0.194215  0.194215  0.194215  0.190083  0.190083  0.243802
# 4    0.500000  0.545455  0.582645  0.623967  0.648760  0.690083  0.694215
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  0.632231  0.648760  0.640496  0.661157
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 397  0.500000  0.533058  0.607438  0.628099  0.657025  0.632231  0.657025
# 398  0.214876  0.219008  0.219008  0.223140  0.210744  0.202479  0.276859
# 399  0.516529  0.462810  0.280992  0.252066  0.247934  0.367769  0.574380
#
#             7         8         9  ...      4087      4088      4089  \
# ...

# %%
from sklearn.model_selection import train_test_split
xtr, xts, ytr, yts = train_test_split(
    df.drop(["target"], axis= 1), df["target"], test_size= .1
)

# %%
from sklearn.linear_model import LogisticRegression

# %%
xts
# Out:
#          0         1         2         3         4         5         6     \
# 326  0.144628  0.123967  0.115702  0.111570  0.123967  0.128099  0.132231
# 139  0.409091  0.500000  0.619835  0.611570  0.619835  0.603306  0.677686
# 88   0.429752  0.475207  0.520661  0.549587  0.553719  0.586777  0.628099
# 148  0.520661  0.549587  0.586777  0.590909  0.607438  0.611570  0.648760
# 396  0.367769  0.367769  0.351240  0.301653  0.247934  0.247934  0.367769
# 234  0.367769  0.454545  0.512397  0.582645  0.590909  0.590909  0.590909
# 315  0.590909  0.747934  0.826446  0.855372  0.842975  0.826446  0.834711
# 261  0.388430  0.462810  0.553719  0.702479  0.760331  0.768595  0.768595
# 191  0.421488  0.512397  0.619835  0.657025  0.590909  0.537190  0.504132
# 71   0.194215  0.223140  0.314050  0.500000  0.636364  0.735537  0.797521
# 19   0.566116  0.619835  0.657025  0.690083  0.702479  0.714876  0.702479
# 289  0.177686  0.140496  0.115702  0.136364  0.177686  0.318182  0.471074
# ...

# %%
model = LogisticRegression(solver= "liblinear", multi_class= "auto")
model.fit(xtr, ytr)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
i = 15

plt.imshow(
    np.array(xts.iloc[i].tolist()).reshape(64,64), cmap="gray"
)
plt.title(f"Aktual = {yts.iloc[i]} | Prediksi = {model.predict([xts.iloc[i]])[0]}")
plt.show()

# %%
model.score(xts, yts)
# Out:
# 0.975
