# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sb

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
ududs = []
for i in df["smoker"]:
    if i == "yes":
        ududs.append(1)
    else:
        ududs.append(0)
df["ududs"] = ududs

jKel = []
for i in df["sex"]:
    if i == "female":
        jKel.append(1)
    else:
        jKel.append(0)
df["jKel"] = jKel
df
# Out:
#       age     sex     bmi  children smoker     region      charges  ududs  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      1
# 1      18    male  33.770         1     no  southeast   1725.55230      0
# 2      28    male  33.000         3     no  southeast   4449.46200      0
# 3      33    male  22.705         0     no  northwest  21984.47061      0
# 4      32    male  28.880         0     no  northwest   3866.85520      0
# ...   ...     ...     ...       ...    ...        ...          ...    ...
# 1333   50    male  30.970         3     no  northwest  10600.54830      0
# 1334   18  female  31.920         0     no  northeast   2205.98080      0
# 1335   18  female  36.850         0     no  southeast   1629.83350      0
# 1336   21  female  25.800         0     no  southwest   2007.94500      0
# 1337   61  female  29.070         0    yes  northwest  29141.36030      1
#
#       jKel
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 1333     0
# 1334     1
# 1335     1
# 1336     1
# 1337     1
#
# [1338 rows x 9 columns]

# %%
df.corr()
# Out:
#                age       bmi  children   charges     ududs      jKel
# age       1.000000  0.109272  0.042469  0.299008 -0.025019  0.020856
# bmi       0.109272  1.000000  0.012759  0.198341  0.003750 -0.046371
# children  0.042469  0.012759  1.000000  0.067998  0.007673 -0.017163
# charges   0.299008  0.198341  0.067998  1.000000  0.787251 -0.057292
# ududs    -0.025019  0.003750  0.007673  0.787251  1.000000 -0.076185
# jKel      0.020856 -0.046371 -0.017163 -0.057292 -0.076185  1.000000

# %%
model = LinearRegression()
model.fit(df[["age", "bmi", "ududs"]], df["charges"])
df["Best Price"] = model.predict(df[["age", "bmi", "ududs"]])
df
# Out:
#       age     sex     bmi  children smoker     region      charges  ududs  \
# 0      19  female  27.900         0    yes  southwest  16884.92400      1
# 1      18    male  33.770         1     no  southeast   1725.55230      0
# 2      28    male  33.000         3     no  southeast   4449.46200      0
# 3      33    male  22.705         0     no  northwest  21984.47061      0
# 4      32    male  28.880         0     no  northwest   3866.85520      0
# ...   ...     ...     ...       ...    ...        ...          ...    ...
# 1333   50    male  30.970         3     no  northwest  10600.54830      0
# 1334   18  female  31.920         0     no  northeast   2205.98080      0
# 1335   18  female  36.850         0     no  southeast   1629.83350      0
# 1336   21  female  25.800         0     no  southwest   2007.94500      0
# 1337   61  female  29.070         0    yes  northwest  29141.36030      1
#
#       jKel    Best Price
# 0        1  26079.218615
# 1        0   3889.737458
# 2        0   6236.798721
# 3        0   4213.213387
# 4        0   5945.814340
# ...    ...           ...
# 1333     0  11291.934816
# 1334     1   3292.899462
# 1335     1   4883.392067
# 1336     1   2097.137324
# 1337     1  37357.672966
#
# [1338 rows x 10 columns]

# %%
sb.heatmap(df.corr(),annot=True, cmap= "hot_r")
plt.show()
